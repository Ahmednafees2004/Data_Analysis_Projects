# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#Reading the data

df = pd.read_csv(r'/Users/nafeesahmed/Downloads/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Sorting out all the data

for col in df.columns:
    missing_percent = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(missing_percent * 100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#Data Types for coloumns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Reogranizing the data types for coloumns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Organising the year coloumn

#df['Yearcorrection'] = df['released'].astype(str).str[:4]

#df
# Out:
# "df['Yearcorrection'] = df['released'].astype(str).str[:4]\n\ndf"

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#Displayes the whole data set all 7,000

#pd.set_option('display.max_rows', None)

# %%
#Removing all duplicates

df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
# Using a scatter plot to show corrlation between budget and the gross revenue

plt.scatter(x=df['budget'], y = df['gross'])

plt.title("Bugdet VS Gross Revenue")
plt.xlabel('Gross Earning')
plt.ylabel('Budget Spent on Film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Creating a regression plot to check the coorlation

sns.regplot(x='budget', y = 'gross', data = df, scatter_kws={"color":"green"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method ='pearson')
# Out:
#                     name  rating  genre      year  released     score  \
# name            1.000000     NaN    NaN -0.377181       NaN  0.164244
# rating               NaN     NaN    NaN       NaN       NaN       NaN
# genre                NaN     NaN    NaN       NaN       NaN       NaN
# year           -0.377181     NaN    NaN  1.000000       NaN  0.097995
# released             NaN     NaN    NaN       NaN       NaN       NaN
# score           0.164244     NaN    NaN  0.097995       NaN  1.000000
# votes           0.063537     NaN    NaN  0.222945       NaN  0.409182
# director             NaN     NaN    NaN       NaN       NaN       NaN
# writer               NaN     NaN    NaN       NaN       NaN       NaN
# star                 NaN     NaN    NaN       NaN       NaN       NaN
# country              NaN     NaN    NaN       NaN       NaN       NaN
# budget          0.390134     NaN    NaN  0.329321       NaN  0.076254
# ...

# %%
df.corr(method ='kendall')
# Out:
#                     name  rating  genre      year  released     score  \
# name            1.000000     NaN    NaN -0.270973       NaN  0.066262
# rating               NaN     NaN    NaN       NaN       NaN       NaN
# genre                NaN     NaN    NaN       NaN       NaN       NaN
# year           -0.270973     NaN    NaN  1.000000       NaN  0.067652
# released             NaN     NaN    NaN       NaN       NaN       NaN
# score           0.066262     NaN    NaN  0.067652       NaN  1.000000
# votes          -0.025641     NaN    NaN  0.331465       NaN  0.300115
# director             NaN     NaN    NaN       NaN       NaN       NaN
# writer               NaN     NaN    NaN       NaN       NaN       NaN
# star                 NaN     NaN    NaN       NaN       NaN       NaN
# country              NaN     NaN    NaN       NaN       NaN       NaN
# budget          0.127273     NaN    NaN  0.224120       NaN -0.000566
# ...

# %%
df.corr(method ='spearman')
# Out:
#                     name  rating  genre      year  released     score  \
# name            1.000000     NaN    NaN -0.382394       NaN  0.066484
# rating               NaN     NaN    NaN       NaN       NaN       NaN
# genre                NaN     NaN    NaN       NaN       NaN       NaN
# year           -0.382394     NaN    NaN  1.000000       NaN  0.099045
# released             NaN     NaN    NaN       NaN       NaN       NaN
# score           0.066484     NaN    NaN  0.099045       NaN  1.000000
# votes          -0.005495     NaN    NaN  0.469829       NaN  0.428138
# director             NaN     NaN    NaN       NaN       NaN       NaN
# writer               NaN     NaN    NaN       NaN       NaN       NaN
# star                 NaN     NaN    NaN       NaN       NaN       NaN
# country              NaN     NaN    NaN       NaN       NaN       NaN
# budget          0.081818     NaN    NaN  0.317336       NaN -0.001403
# ...

# %%
'''correlation_matrix = df.corr(method= 'pearson')
sns.heatmap(correlation_matrix, annot = True)

plt.title("Numeric Feature Matrix")
plt.xlabel('Movie Feature')
plt.ylabel('Movie Feature')

plt.show'''

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = df.corr(method='pearson')

# Set the size of the heatmap
plt.figure(figsize=(8, 6))  # Adjust the size as needed (width, height)

# Create the heatmap with annotation size
sns.heatmap(correlation_matrix, annot=True, annot_kws={"size": 8}, cmap='coolwarm', linewidths=0.5)

# Add titles and labels
plt.title("Numeric Feature Matrix", fontsize=14)
plt.xlabel('Movie Feature', fontsize=12)
plt.ylabel('Movie Feature', fontsize=12)

# Display the plot
plt.tight_layout()  # Adjusts layout for better fitting
plt.show()

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                     name  rating  genre      year  released     score  \
# name            1.000000     NaN    NaN  0.031790       NaN -0.003768
# rating               NaN     NaN    NaN       NaN       NaN       NaN
# genre                NaN     NaN    NaN       NaN       NaN       NaN
# year            0.031790     NaN    NaN  1.000000       NaN -0.044981
# released             NaN     NaN    NaN       NaN       NaN       NaN
# score          -0.003768     NaN    NaN -0.044981       NaN  1.000000
# votes           0.031385     NaN    NaN  0.312401       NaN -0.009749
# director             NaN     NaN    NaN       NaN       NaN       NaN
# writer               NaN     NaN    NaN       NaN       NaN       NaN
# star                 NaN     NaN    NaN       NaN       NaN       NaN
# country              NaN     NaN    NaN       NaN       NaN       NaN
# budget          0.014120     NaN    NaN  0.300621       NaN -0.012642
# ...

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized






'''df_numerized = df.copy()
# Fill NaN values with 0 or a value of your choice
df_numerized.fillna(0, inplace=True)

# Convert non-numeric columns to categorical codes
for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype == 'object':
        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes
df_numerized = df.copy()

# Convert non-numeric columns to categorical codes
for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype == 'object':
        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes

# Replace -1 (which indicates missing values) with 0 or another placeholder
df_numerized.replace(-1, 0, inplace=True)
df_numerized = pd.get_dummies(df, drop_first=True)

# Check the data types of the columns
print(df.dtypes)'''
# Out:
# "df_numerized = df.copy()\n# Fill NaN values with 0 or a value of your choice\ndf_numerized.fillna(0, inplace=True)\n\n# Convert non-numeric columns to categorical codes\nfor col_name in df_numerized.columns:\n    if df_numerized[col_name].dtype == 'object':\n        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes\ndf_numerized = df.copy()\n\n# Convert non-numeric columns to categorical codes\nfor col_name in df_numerized.columns:\n    if df_numerized[col_name].dtype == 'object':\n        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes\n\n# Replace -1 (which indicates missing values) with 0 or another placeholder\ndf_numerized.replace(-1, 0, inplace=True)\ndf_numerized = pd.get_dummies(df, drop_first=True)\n\n# Check the data types of the columns\nprint(df.dtypes)"

# %%
correlation_matrix = df.corr(method= 'pearson')
sns.heatmap(correlation_matrix, annot = True)

plt.title("Numeric Feature Matrix")
plt.xlabel('Movie Feature')
plt.ylabel('Movie Feature')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_numerized.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name            name              1.000000
#                 rating                 NaN
#                 genre                  NaN
#                 year             -0.377181
#                 released               NaN
#                 score             0.164244
#                 votes             0.063537
#                 director               NaN
#                 writer                 NaN
#                 star                   NaN
#                 country                NaN
#                 budget            0.390134
#                 gross             0.275889
#                 company                NaN
#                 runtime           0.379230
#                 Yearcorrection         NaN
# rating          name                   NaN
#                 rating                 NaN
#                 genre                  NaN
#                 year                   NaN
#                 released               NaN
#                 score                  NaN
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget          Yearcorrection   -0.745248
# Yearcorrection  budget           -0.745248
# name            year             -0.377181
# year            name             -0.377181
# Yearcorrection  score            -0.136418
# score           Yearcorrection   -0.136418
# runtime         Yearcorrection    0.055838
# Yearcorrection  runtime           0.055838
# votes           name              0.063537
# name            votes             0.063537
# score           budget            0.076254
# budget          score             0.076254
# year            score             0.097995
# score           year              0.097995
# year            runtime           0.120811
# runtime         year              0.120811
# name            score             0.164244
# score           name              0.164244
#                 gross             0.186258
# gross           score             0.186258
# votes           year              0.222945
# year            votes             0.222945
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5 ]
high_corr
# Out:
# gross           Yearcorrection    0.533237
# Yearcorrection  gross             0.533237
# gross           votes             0.630757
# votes           gross             0.630757
# gross           budget            0.740395
# budget          gross             0.740395
# Yearcorrection  year              0.924799
# year            Yearcorrection    0.924799
# votes           Yearcorrection    0.926848
# Yearcorrection  votes             0.926848
# name            name              1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# votes           votes             1.000000
# score           score             1.000000
# year            year              1.000000
# runtime         runtime           1.000000
# Yearcorrection  Yearcorrection    1.000000
# dtype: float64

# %%
# Given the data analysis it can be seen that the amount of votes and the budget have the highest correlation while the company has low correlation.
